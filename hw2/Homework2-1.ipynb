# %% [markdown]
# # Homework 2: Problem Formulation Practice
# **CISC 440 – Artificial Intelligence**
# **Chapter 3 → Preparing for Search Algorithms**
#
# **Due:** *(see Canvas)*
# **Submission:** Upload this notebook to Canvas
# **Collaboration:** You may work with **one partner** (max 2 students). Submit one file with both names.
#
# ## Name(s)
# 1. Ethan Lukandwa
# 2. Branden Shaffa
#
# ## Academic Integrity / Honor Code
# By placing my initials below, I affirm that I have completed all parts of this assignment in accordance with the academic integrity guidelines outlined in the course syllabus and course policies. Specifically, I confirm that:
#
# 1. I did not receive unauthorized assistance from anyone other than the course instructor (Prof. Akram).
# 2. I did not provide unauthorized assistance to anyone else.
# 3. I did not use AI tools, online solution sources, or any other external platform to generate or complete my answers.
#
# **Time spent on the assignment (excluding reading):** _________ hours
#
# **My impression of the assignment (1 = lowest, 5 = highest):**
# - Difficulty (1–5): _________
# - Enjoyment  (1–5): _________
# - Usefulness (1–5): _________
# - Comments (optional):
#
# **Initials:** __EL____
# ## Time spent (excluding reading): __6__ hours
#
# ## Overview
#
# Before we apply search algorithms like BFS, UCS, or A*, we must first define the problem correctly.
#
# In this assignment, you will formally formulate three problems as search problems using the framework discussed in class.
#
# You are NOT implementing search algorithms.
# You are defining the structure that the search will operate on.
#
# ## Learning Objectives
#
# By completing this homework, you will be able to:
#
# - Define a state space precisely
# - Identify valid actions and transitions
# - Specify goal conditions clearly
# - Define path cost functions
# - Understand how formulation choices affect search behavior
#
# ## Submission Format
#
# Submit the **same file with completed code** containing:
#
# - Clear structured sections for each problem
# - Diagrams if helpful
# - Mathematical definitions where appropriate
# - Concise but precise explanations

# %% [markdown]
# # Written Part

# %% [markdown]
# ## Task 1: Problem — The Locked Glass Boxes
#
# ## Scenario
#
# There are **six locked glass boxes arranged in a straight line**.
#
# - Box 1 contains a key that unlocks **Box 2**
# - Box 2 contains a key that unlocks **Box 3**
# - Box 3 contains a key that unlocks **Box 4**
# - Box 4 contains a key that unlocks **Box 5**
# - Box 5 contains a key that unlocks **Box 6**
# - Box 6 contains a **banana**
#
# You are initially holding the key to **Box 1**.
#
# Your objective is to obtain the banana.
#
# ## Your Task
#
# Formulate this scenario as a **complete search problem**.
#
# Provide clear definitions for the following components:
#
# ### 1. State Space
# - What information must be included in a state?
# A state has to capture everything relevant to future decisions. For this specific problem, we need to see which boxes are unlocked, which keys I currently have, and whether I have the banana
# - How can a state be represented formally?
# We can represent it as State= (UnlockedBoxes, KeysHold, BananaStatus)
#
#
# ### 2. Initial State
# - What is true at the beginning?
# #### At the beginning, all boxes are locked, I only have the key to Box 1, also I do not have the banana
#
# ### 3. Goal State
# - When is the problem considered solved?
# #### The goal state is what we are trying to accomplish. In this case, once we have the banana it is complete.
#
# ### 4. Actions
# - What actions are available at each step?
# #### Action permitted at the current state. In this case, the action available is to unlock the box
# - Under what conditions can each action be applied?
# #### If the current box is locked and also if we have the key to said box
#
# ### 5. Transition Model
# - What happens when an action is applied?
# #### Unlocking a box adds it to the set of unlocked boxes. If you unlock the current box i, you then have access to box i+1. If you unlock box 6 you get the banana ####
# - How does the state change?
# #### The state changes by increasing progress
#
# ### 6. Path Cost
# - What is the cost of each action?
# #### Each action has a cost of 1.
# - Is the problem one of minimizing steps?
# #### Yes, the problem is formulated as minimizing the number of unlock actions.
#
# ## Important
# Your answer should:
#
# - Clearly define all components.
# - Be written in formal problem formulation style (as discussed in class).
# - Not include any code.

# %% [markdown]
# ## Answer:

# %% [markdown]
# ## Task 2
# - There is an 𝑛 × 𝑛 grid of squares, each square initially being either unpainted floor or a bottomless pit. You start standing on an unpainted floor square and can either paint the square under you or move onto an adjacent unpainted floor square. You want the whole floor painted.

# %% [markdown]
# ## Answer:
# - The state space includes everything needed, we must determine valid moves, and also determine whether the goal is satisfied. We are tracking the agent's current position and also which floor squares have been painted.
#
# - The initial state would be the agent is standing on a specific floor square and also no floor squares have been painted yet.
#
# - The goal state is when every floor square in the grid has been painted. It doesn't matter where the agent is standing once all floor squares are painted.
#
# - The agent can perform two actions, first is paint the square it is currently standing on. Second, is move one square up, down, left, or right. Also, the paint action can only be done if the current square has not already been painted.
# It can only be performed if the destination square is within the grid boundaries and if the destination square is a floor square and not a pit.
#
# - If the agent chooses to paint, the square it is currently standing on becomes painted, also the agent's position does not change.
#
# - Each action, whether painting or moving, has a cost of one. Also, the total path cost is the total number of actions taken.

# %% [markdown]
# ## Task 3
#
# Your objective is to guide a robot through a 5 × 6 maze to reach the exit. The robot
# begins at the leftmost corner (0,0), facing east. It can be rotated to face north, east, south, or
# west. The robot can move forward a specified distance but will stop upon encountering a wall.
#
# - Walls are represented by “#”, indicating obstacles the robot cannot pass through.
# - Open paths are represented by “.” where the robot can move freely.
#
# 1. Formulate this problem.
# 2. What is the size of the state space?
# 3. Identify the intersections within the maze.
# 4. Outline the steps the robot will take to reach the goal.
# 5. Since turns are only necessary at intersections of two or more corridors, reformulate the problem using this approach. What is the new state space size?
#
# <img src="attachment:dced5a88-9990-4cc9-a158-27261a381165.png" width="300"/>

# %% [markdown]
# ## Answer

# %% [markdown]
# # Programming Part

# %% [markdown]
# # Problem 1 — DogCat Word Transformation
#
# ## Scenario
#
# We want to transform one word into another by changing one letter at a time.
#
# Example:
#
#
# At each step:
#
# - You may change exactly **one letter**
# - Each letter has a cost
# - The cost of a move is the cost of the new letter inserted
#
# ## Your Task
#
# Formulate this as a search problem by defining:
#
# ### State Space
# - What is a state?
# - How is a word represented?
#
# ### Initial State
# Example: `"DOG"`
#
# ### Goal State
# Example: `"CAT"`
#
# ### Actions
# - What actions are available from any word?
# - How many possible actions per position along with the cost?
#
# ### Transition Model
# - What does applying an action produce?
#
# ### Path Cost
# Define the cost function mathematically.
# **Cost model**:
# - Letters in {a, e, i, l, n, o, r, s, t, u} cost 1.
# - Letters in {b, d, g, c, m, p, f, h, v, w, y} cost 2.
# - Letters in {k, j, x, q, z} cost 4.
#
# ### Constraint
# Ensure each generated word is valid by checking against legal_word. here is the legal word list:
#
# words = {
#     'ask', 'asp', 'ass', 'ads', 'apt', 'art', 'arm', 'ail', 'aim', 'age', 'ate', 'ale', 'ade', 'ark',
#     'bat', 'ban', 'bit', 'big', 'bog', 'bag', 'bum', 'bud',
#     'can', 'cab', 'cat', 'cog', 'cot', 'cub', 'cut',
#     'dog', 'don', 'dot', 'dab', 'din', 'dub',
#     'eat', 'ear', 'eel', 'eak', 'elm', 'elk', 'ebb', 'eve', 'ewe', 'eye',
#     'fat', 'fan', 'fun', 'far', 'fir', 'few', 'fly', 'fob', 'for', 'fop',
#     'gas', 'gym', 'gag', 'god', 'gut', 'gnu', 'gin', 'gig', 'goo', 'guy',
#     'hit', 'hot', 'hat', 'him', 'ham', 'hid', 'hop',
#     'ill', 'ilk', 'ire', 'ivy', 'irk', 'ink', 'inn', 'ion',
#     'job', 'jog', 'jug', 'jut', 'jag', 'jib', 'jam', 'jar',
#     'kid', 'kib', 'keg', 'ken',
#     'lip', 'lap', 'lid', 'lop', 'lye', 'lam', 'lad',
#     'man', 'men', 'mop', 'map', 'mad', 'mat', 'mid',
#     'nut', 'nor', 'not', 'nit', 'nab', 'nob',
#     'oat', 'oil', 'oar', 'our', 'own', 'ort',
#     'pup', 'pop', 'pin', 'pad', 'pat',
#     'quo', 'qua',
#     'rot', 'rut', 'ran', 'rid', 'rye', 'rat', 'ray', 'rap', 'rip',
#     'sot', 'sod', 'sin', 'sad', 'sat', 'sip', 'sap', 'sag',
#     'tot', 'tad', 'tip', 'ten', 'thy', 'toy', 'top',
#     'use', 'urn', 'ugh', 'ups',
#     'van', 'vim', 'vat', 'vet', 'vex', 'vow',
#     'was', 'wip', 'wad', 'web', 'wow', 'wok', 'why', 'who', 'way', 'won', 'wan',
#     'yes', 'yen', 'yet', 'yip', 'you',
#     'zoo', 'zen', 'zip', 'zap'
#     }

# %%
import heapq

words = {
    'ask','asp','ass','ads','apt','art','arm','ail','aim','age','ate','ale','ade','ark',
    'bat','ban','bit','big','bog','bag','bum','bud',
    'can','cab','cat','cog','cot','cub','cut',
    'dog','don','dot','dab','din','dub',
    'eat','ear','eel','eak','elm','elk','ebb','eve','ewe','eye',
    'fat','fan','fun','far','fir','few','fly','fob','for','fop',
    'gas','gym','gag','god','gut','gnu','gin','gig','goo','guy',
    'hit','hot','hat','him','ham','hid','hop',
    'ill','ilk','ire','ivy','irk','ink','inn','ion',
    'job','jog','jug','jut','jag','jib','jam','jar',
    'kid','kib','keg','ken',
    'lip','lap','lid','lop','lye','lam','lad',
    'man','men','mop','map','mad','mat','mid',
    'nut','nor','not','nit','nab','nob',
    'oat','oil','oar','our','own','ort',
    'pup','pop','pin','pad','pat',
    'quo','qua',
    'rot','rut','ran','rid','rye','rat','ray','rap','rip',
    'sot','sod','sin','sad','sat','sip','sap','sag',
    'tot','tad','tip','ten','thy','toy','top',
    'use','urn','ugh','ups',
    'van','vim','vat','vet','vex','vow',
    'was','wip','wad','web','wow','wok','why','who','way','won','wan',
    'yes','yen','yet','yip','you',
    'zoo','zen','zip','zap'
}

COST = {}
for c in 'aeilnorstu': COST[c] = 1
for c in 'bdgcmpfhvwy': COST[c] = 2
for c in 'kjxqz': COST[c] = 4

class DogCat:
    def __init__(self, start, goal):
        self.start = start.lower()
        self.goal  = goal.lower()

    def actions(self, word):
        result = []
        for i in range(len(word)):
            for c in 'abcdefghijklmnopqrstuvwxyz':
                if c != word[i]:
                    new = word[:i] + c + word[i+1:]
                    if new in words:
                        result.append((new, COST[c]))
        return result

    def solve(self):
        heap = [(0, self.start, [self.start])]
        visited = {}
        while heap:
            cost, word, path = heapq.heappop(heap)
            if word == self.goal:
                print(f"Start: {path[0].upper()}")
                for i in range(1, len(path)):
                    ch = next(j for j in range(len(word)) if path[i][j] != path[i-1][j])
                    print(f"  -> {path[i].upper()}  (cost {COST[path[i][ch]]})")
                print(f"Total cost: {cost}")
                return
            if word in visited: continue
            visited[word] = cost
            for new_word, c in self.actions(word):
                if new_word not in visited:
                    heapq.heappush(heap, (cost + c, new_word, path + [new_word]))
        print("No solution found.")

DogCat("dog", "dot").solve()
# Out:
# Start: DOG
#   -> DOT  (cost 1)
# Total cost: 1

# %% [markdown]
# # Problem 2 — Tower of Hanoi
#
# ## Scenario
#
# We want to move a stack of **N disks** from a start peg to a goal peg using an auxiliary peg.
#
# ### Rules
#
# - Only one disk may be moved at a time.
# - Only the **top disk** of any peg may be moved.
# - A larger disk may **never** be placed on top of a smaller disk.
#
# ## Example (N = 3)
#
# Initial state:
#
#     A = (3, 2, 1)
#     B = ()
#     C = ()
#
# Goal state:
#
#     A = ()
#     B = ()
#     C = (3, 2, 1)
#
# ## Your Task
#
# Formulate this as a search problem by defining the following components.
#
# ### State Space
#
# - What is a state?
# - How do you represent the peg configuration?
#
# ### Initial State
#
# For N disks starting on peg 0:
#
# ### Goal State
#
# All disks stacked on the goal peg (e.g., peg 2):
#
# ### Actions
#
# - What actions are available from any state?
#
# A move is legal only if:
#
# 1. The source peg is not empty.
# 2. The destination peg is empty OR its top disk is larger than the disk being moved.
#
# ### Transition Model
#
# Applying action (i, j):
#
# 1. Remove the top disk from peg i.
# 2. Place it on peg j.
# 3. Return the updated state.
#
# ### Path Cost
#
# Each move costs 1.
#
# Mathematically:
#
#     g(child) = g(parent) + 1
#
# The total cost equals the number of moves.

# %%
class TowerOfHanoi{





}

# %% [markdown]
# # Problem 3 — Toggle-It Puzzle
#
# ### Scenario
# You are given an **N×N grid** of binary values:
#
# - `0` = OFF
# - `1` = ON
#
# Your goal is to transform the grid from an initial state to a goal state
# (typically **all zeros**).
#
# ### Toggle Rule: Neighborhood Toggle
#
# A move chooses one cell (by index or (row, col)) and flips:
#
# - the chosen cell itself
# - its **up** neighbor (if it exists)
# - its **down** neighbor (if it exists)
# - its **left** neighbor (if it exists)
# - its **right** neighbor (if it exists)
#
# Flipping means:
#
# - `0 → 1`
# - `1 → 0`
#
# **No diagonals**.
# If a neighbor is outside the grid (edge/corner), ignore it.
#
# ### Example: 2×2 Indexing
#
# Use row-major indexing:
#
# 0 1
# 2 3
#
# - Toggle `0` affects cells `{0, 1, 2}`
# - Toggle `1` affects cells `{1, 0, 3}`
# - Toggle `2` affects cells `{2, 0, 3}`
# - Toggle `3` affects cells `{3, 1, 2}`
#
#
# ### State Representation
# Represent a state as a binary string of length `N*N`:
#
# For a 2×2 grid:
#
# - `"0011"` represents:
#
# 00
#
# 11
#
#
# - Goal `"0000"` represents:
#
#
# 00
#
# 00
#
#
# ### Search Problem Components
#
# #### State Space
# All binary grids of size N×N (equivalently all strings of length N² over {0,1}).
#
# #### Initial State
# Example: `"0011"`
#
# #### Goal State
# Example: `"0000"`
#
#
# #### Actions
#
# At any state, an action consists of choosing one cell index:
#
#
# \[
# \text{action} \in \{0,1,\dots,N^2 - 1\}
# \]
#
#
# Therefore, each state has exactly \(N^2\) possible actions.
#
#
#
# #### Transition Model
# Applying action `i` flips the chosen cell and its valid neighbors (up/down/left/right),
# producing a new grid configuration.
#
# #### Path Cost
# Each toggle costs 1
#
#
# ## Expected Output Style (Example)
#
# **Testing 2x2 problem**
# Solving `0011 => 0000`
#
# Example of a valid solution trace:
#
# initial
#
# 00
#
# 11
#
# Toggle 0 =>
#
# 11
#
# 01
#
# Toggle 1 =>
#
# 00
#
# 00

# %%
class ToogleIt{


}
